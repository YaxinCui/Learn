# %% [markdown]
# ## Philosophy
# 设计哲学
#
# - 容易上手使用
# - 提供SOTA模型

# %% [markdown]
# ### 主要概念
#
# - Model classes
# - configuration classes
# - Tokenizer classes
#
#
# 通过from_pretrained()倒入模型，通过save_pretrained()保存模型。
