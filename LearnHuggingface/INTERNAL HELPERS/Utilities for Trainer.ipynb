# %% [markdown]
# ### Utilities for Trainer
# - Utilities
# - Callbacks internals
# - Distributed Evaluation
# - Debug Utilities

# %% [markdown]
# ### Utilities
# ```
# class transformers.EvalPrediction
# (predictions, label_ids)
#
# class trnasformers.IntervalStrategy
# (value, names, module, qualname, type, start)
#
# transformers.set_seed
#
# transformers.torch_distributed_zero_first
# (local_rank)
#
#
# ```

# %% [markdown]
# ### Distributed Evaluation
#
# ```
# class transformers.trainer_pt_utils.DistributedTensorGatherer
# (world_size, num_samples, make_multiple_of, padding_index)
#
# class transformers.HfArgumentParser
# (dataclass_types, **kwargs)
#
# parse_dict
# parse_json_file

# %% [markdown]
# ### Debug Utilities
# class transformers.debug_utils.DebugUnderflowOverflow
# (model, max_frames_to_save, trace_batch_nums, abort_after_batch_num)
