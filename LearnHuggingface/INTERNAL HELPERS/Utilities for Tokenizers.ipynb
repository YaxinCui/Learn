# %% [markdown]
# 这页介绍tokenizer函数，主要介绍 PreTrainedTokenizerBase这个类，包括这个类的继承 PreTrainedTokenizer和PreTrainedTokenizerFast，还有混合的SpecialTokensMixin.

# %% [markdown]
# ### PreTrainedTokenizerBase(**kwargs)
#
# ```
# model_max_length
# model_input_names
# bos_token
# eos_token
# unk_token
# sep_token
# cls_token
# mask_token
# additional_special_tokens
# ```
