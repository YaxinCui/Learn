# %% [markdown]
# ### General Utilities
# - Enums and namedtuples
# - Special Decorators
# - Special Properties
# - Other Utilities

# %% [markdown]
# ### Enums and namedtuples
# class transformers.file_utils.ExplicitEnum
# (value, names, module, qualname, type, start)
#
# class transformers.file_utils.PaddingStrate
#
# class transformers.TensorType

# %% [markdown]
# ### Special Properties
# class transformers.file_utils.cached_property
# (fget, fset, fdel, doc)

# %% [markdown]
# ### Other Utilities
# class transformers.file_utils._LazyModule
# (name, module_file, import_structure, module_spec, extra_objects)
