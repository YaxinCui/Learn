# %% [markdown]
# 本页列出了库的所有自定义图层，为建模提供了实用程序函数。
#
# 只有当研究库中模型的代码时，其中大多数才有用。

# %% [markdown]
# # Pytorch custom modules
#
# class transformers.Conv1D(nf, nx)
#
# 被用在OpenAI GPT上
#
# weights are tranposed是什么意思？
#
# class transformers.modeling_utils.PoolerStartLogits(config: PretrainedConfig)
#
# forward
# (hidden_states: FloatTensor, p_mask: typing.Optional[torch.FloatTensor] = None) -> torch.FloatTensor
#
# hidden_states(torch.FloatTensor of shape(batch_size, seq_len, hidden_size))
#
# p_mask(torch.FloatTensor of shape(batch_size, seq_len))
#
#
# class transformers.modeling_utils.PoolerEndLogits(config)
#
# 计算squad最后的百分比
# forward(hidden_states: FloatTensor, start_states: start_positions: p_mask,)
#
#
# class transformers.modeling_utils.PoolerAnswerClass(config)
# forward(hidden_states: FloatTensor, start_states: )
#
# class transformers.modeling_utils.SquadHeadOutput
# (loss: ,start_top_log_probs, start_top_index, end_top_log_probs, end_top_index, cls_logits)
#
# class transformers.modeling_utils.SQuADHead(config)
# forward(hidden_states: start_positions: end_positions, cls_index, is_impossible, p_mask, return_dict)
#
# class transformers.modeling_utils.SequenceSummary(config)
# summary_type: last, first, mean, cls_index, attn
# summary_use_proj
# summary_proj_to_labels
# summary_activation
# summary_first_dropout
# summary_last_dropout

# %% [markdown]
# ### Pytorch Helper Functions
#
# transformers.apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensor)
# forward_fn, chunk_size, chunk_dim, input_tensors
#
# transformers.modeling_utils.find_pruneable_heads_and_indices(heads, n_heads, head_size, already_pruned_heads)
#
# transformers.prune_layer(layer, index, dim)
# layer, index, dim
#
# transformers.modeling_utils.prune_conv1d_layer
#
# transformers.shape_list
