# %% [markdown]
# ### Utilities for Generation
# 这里有这些函数，generate(), greedy_search(), sample(), beam_search(), beam_sample(), group_beam_search()
#
# - Generate Outputs
#   - GreedySearchOutput
#   - SampleOutput
#   - BeamSearchOutput
#   - BeamSampleOutput
# - LogitsProcessor
# - StoppingCriteria
# - BeamSearch
# - Utilities

# %% [markdown]
# ### Generate Outputs
# generate()会生成ModelOutput的子类
#
# #### GreedySearchOutput
#
# ```
# class transformers.generation_utils.GreedySearchDecoderOnlyOutput
# (sequence, scores, attentions, hidden_states)
#
# class transformers.generation_utils.GreedySearchDecoderOutput
# (sequences, encoder_attentions, encoder_hidden_states, decoder_attentions, cross_attentions, decoder_hidden_states)
#
# class transformers.generatio_flax_utils.FlaxGreedySearchOutput
# (sequences)
# ```
#
# #### SampleOutput
# ```
# class transformers.generation_utils.SampleDecoderOnlyOutput
# (sequences, scores, attentions, hidden_states)
#
# class transformers.generation_utils.SampleEncoderOutput
# (sequences, encoder_attentions, encoder_hidden_states, decoder_attentions, cross_attentions, decoder_hidden_states)
