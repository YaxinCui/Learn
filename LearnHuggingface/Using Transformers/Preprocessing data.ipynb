# %% [markdown]
# ## Preprocessing data
# - Base Use
#     1. Tokenizer会分割text为词，通过AutoTokenizer引入分词工具。
#     2. __call__方法，对一个句子，或一个batch的句子进行处理
#     3. decode方法，解码
#     4.
# - Preprocessing pairs of sentences
#   - 处理一对句子，a、b句
#   -
# - Everything you always wanted to know about padding and truncation
# - Pre-tokenized inputs
#   - 对于NER或POS任务，会预先分割为词，通过在tokenizer call方法中，把is_split_into_words标记为true，可以得到正确的token。
