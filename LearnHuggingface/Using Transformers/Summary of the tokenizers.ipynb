# %% [markdown]
# ## Summary of the tokenizers
#
# - Introduction
#     - Subword tokenization
# - Byte-Pair Encoding (BPE)
#     - Byte-level BPE

# %% [markdown]
# 字节对编码 （BPE）、WordPiece 和 SentencePiece，
#
# Bert使用WordPiece
