# %%
print("Hello, World!")

# %% [markdown]
# ## Python3 简介
# 高层次，结合了解释性、编译性、互动性、面向对象的脚步语言。
# 【个人感觉解释性跟互动性的相关性很大，虽然python是面向对象的，我却很少用到这个特性。想一想到底为什么没用到。】

# %% [markdown]
# ### Python特点
# 1. 易于学习
# 2. 易于阅读
# 3. 易于维护
# 4. 有广泛的标准库
# 5. 互动
# 6. 可移植
# 7. 可拓展
# 8. 数据库
# 9. GUI编程
# 10. 可嵌入

# %% [markdown]
# ## Python3 环境搭建
#
# ### 运行Python
#
# Python命令行参数
# |选项|描述 |
# |---|---|
# |-d|在解析时显示调试信息 不明白|
# |-O | 生成优化代码 ( .pyo 文件 )(感觉会有用)
# |-S | 启动时不引入查找Python路径的位置 不明白

# %% [markdown]
# ## Python3基础语法

# %%
### python保留字

import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
### 注释

# 第一个注释
print("Hello, Python!") # 第二个注释

'''
第三个注释
'''

"""
第四个注释
"""
# Out:
# Hello, Python!
# '\n第四个注释\n'

# %%
### 多行语句

# %% [markdown]
# ## Python3 基本数据类型
#
#
# ### 标准数据类型
#
# Python3 的六个标准数据类型中：
#
# 不可变数据（3 个）：Number（数字）、String（字符串）、Tuple（元组）；
# 可变数据（3 个）：List（列表）、Dictionary（字典）、Set（集合）。
#
# ### Number（数字）
# int、float、bool、complex
#
# ```
# 注意：Python3 中，bool 是 int 的子类，True 和 False 可以和数字相加， True==1、False==0 会返回 True，但可以通过 is 来判断类型。
# ```
#
# 可以使用del语句删除一些对象引用。
# !如何判断一个对象是否是引用对象？
#
#
# ### List（列表）
#
# list = [ 'abcd', 786 , 2.23, 'runoob', 70.2 ]
# tinylist = [123, 'runoob']
#
# print (list)            # 输出完整列表
# print (list[0])         # 输出列表第一个元素
# print (list[1:3])       # 从第二个开始输出到第三个元素
# print (list[2:])        # 输出从第三个元素开始的所有元素
# print (tinylist * 2)    # 输出两次列表
# print (list + tinylist) # 连接列表
#
# a = [1,2,3,4,5] # a[::-1]倒转列表 为[5,4,3,2,1]
#
# ### Tuple（元组）
#
# 虽然tuple的元素不可改变，但它可以包含可变的对象，比如list列表。
#
# 构造包含 0 个或 1 个元素的元组比较特殊，所以有一些额外的语法规则：
#
# tup1 = ()    # 空元组
# tup2 = (20,) # 一个元素，需要在元素后添加逗号
#
# ### Set（集合）
#
# 基本功能是进行成员关系测试和删除重复元素。
# ！这里说的重复元素，是指值相同吗？如果是两个list相同，会不会被删除呢？
# ! 回答，list不能被加入Set中去。
#
# ### Dictionary（字典）
#
# 另外，字典类型也有一些内置的函数，例如clear()、keys()、values()等。
#
# 注意：
#
# 1、字典是一种映射类型，它的元素是键值对。
# 2、字典的关键字必须为不可变类型，且不能重复。
# 3、创建空字典使用 { }。

# %% [markdown]
# ## Python3 解释器
#
# 有交互式编程和脚本式编程。

# %% [markdown]
# ## Python3 运算符
#
#
# ### 算术运算符
# + - * / **(取幂，而不是^) // %
#
# ### 比较（关系）运算符
# == != > < >= <=
#
# ### 赋值运算符
# = += -= *= /= **= //= %=
# 另外有海象运算符 :=，可在表达式内部赋值
#
# ### 位运算符
# & | ~ ^（异或符）<< >>
#
# ### 逻辑运算符
# and or not
#
# ### 成员运算符
# in, not in
#
#
# ### 身份运算符
# is, is not
# id() 函数用于获取对象内存地址。
#
# ### 运算符优先级
# （不背，遇到就用括号）

# %% [markdown]
# ## Python3 数字(Number)
#
# Python3 整型是没有限制大小的
#
# ### 数学函数
# abs(x)：返回绝对值
# ceil(x)：返回数字的上入整数
# exp(x)：返回e的x次幂
# fabs():fabs是专门求浮点型的绝对值的，浮点型时精度要更高一些。
# floor(x):返回数字的下舍整数，如math.floor(4.9)返回 4
# log()：以e为底
# log10()
# max()
# min
# modf：返回x的整数部分和小数部分
# pow(x, y)
# round(x [,n])：四舍五入n位
# sqrt(x)：返回数字x的平方跟
# ！ 发现没有开n次方的
#
#
# ### 随机数函数
#
# choice(seq)：随机挑选一个元素，比如random.choicef
# randrange ([start,] stop [,step])	从指定范围内，按指定基数递增的集合中获取一个随机数，基数默认值为 1
# random()随机生成一个[0, 1)范围的实数
# shuffle(lst)	将序列的所有元素随机排序
#
# ### 三角函数
# acos
# asin
# atan
# atan2
# cos
# hypot
# sin
# tan
# degrees：把弧度转换为角度
# radians：角度转换为弧度

# %% [markdown]
# ## Python3 字符串
#
# ### python访问字符串中的值
# 使用[]来截取字符串。
#
# ### python字符串更新
#
# ### f-string
# 字面量格式化字符串，新的格式化字符串的语法。
#
# ```
# >>> name = 'Runoob'
# >>> f'Hello {name}'  # 替换变量
# 'Hello Runoob'
# >>> f'{1+2}'         # 使用表达式
# '3'
#
# >>> w = {'name': 'Runoob', 'url': 'www.runoob.com'}
# >>> f'{w["name"]}: {w["url"]}'
# 'Runoob: www.runoob.com'
#
# ```
#
# ### Python的字符串内建函数
# capitalize()
#
# center
#
# count
#
# bytes.decode()
#
# encode()
#
# endswith
#
# expandtabs
#
# find
#
# isalnum
#
# isalpha
#
# isdigit
#
# ...

# %% [markdown]
# ## Python3 列表
#
#
# ### 访问列表的值
#
# ### 更新列表
#
# ### 删除列表元素
#
# del
#
# ### Python列表脚步操作符
#
# ### Python列表截取与拼接
#
# ### Python列表函数和方法
# len
# max
# min
# list
#
# append
# count
# extend
# index
# insert
# pop
# remove
# reverse()
# sort
# clear
# copy

# %% [markdown]
# ## Python3 元组
#
# ### 访问元组
#
# ### 修改元组
#
# ### 删除元组
#
# ### 元组运算符
#
# ### 元组索引，截取
#
# ### 元组内置函数

# %% [markdown]
# ## Python3 字典
#
# ### 创建空字典
# {} dict
#
# ### 访问字典里的值
#
# ### 修改字典
#
# ### 删除字典元素
# del dict['Name']
#
# ### 字典内置函数&方法
# len
# str
# clear()
# copy()：返回字典的浅复制
# fromkeys()
# get
# items()
# setdefault(key, default)
# update
# values
# pop
# popitem

# %% [markdown]
# ## Python3 集合
# 可以使用大括号{}或set()创建，但空集合只能由set()创建。
# - | & ^
#
# ### 集合的基本操作
# 1. 添加元素
# 2. add
# 3. update
# 4. 移除元素
# 5. remove | discard
# 6. 随机删除元素 pop
#
# 计算元素个数
# 清空集合clear()

# %% [markdown]
# ## Python3 编程第一步
#
# 输出斐波那契数列

# %% [markdown]
# ## Python3 条件控制
# if elif else
# 在python中没有switch-case语句

# %% [markdown]
# ## Python3 循环语句
# 循环语句有for和while
#
# while循环可以结合else语句使用。
#
# for循环也可以结合else语句使用。
#
# break和continue语句及循环中的else子句。
#
# pass是空语句，为了保持程序结构的完整性。

# %% [markdown]
# ## Python3 迭代器与生成器
#
# 迭代器有两个基本的方法：iter()和next()
#
# iter(list)
# next()
#
# 创建一个类，重构__iter__和__next__方法，就是一个迭代器。
#
# 生成器
# 在python中，使用了yield的函数被称为生成器 generator。
# 生成器是一个返回迭代器的函数，只能用于迭代操作。
# 在调用生成器运行的过程中，每次遇到yield函数会暂停并保存当前所有的运行信息，返回yield的值，并在下一次执行next()方法时，从当前位置继续运行。

# %% [markdown]
# ## Python3 函数
#
# ### 定义函数
#
# ### 参数传递
# 可更改mutable与不可更改immutable对象
#
# 不可变类型：变量赋值 a=5 后再赋值 a=10，这里实际是新生成一个 int 值对象 10，再让 a 指向它，而 5 被丢弃，不是改变 a 的值，相当于新生成了 a。
#
# 可变类型：变量赋值 la=[1,2,3,4] 后再赋值 la[2]=5 则是将 list la 的第三个元素值更改，本身la没有动，只是其内部的一部分值被修改了。
#
# Python函数的参数传递
# 对于不可变类型，类似c++的值传递。
# 对于可变类型类似c++的引用传递，传值后，函数外部的变量也会受影响。
#
#
# 参数
# 以下是调用函数时可使用的正式参数类型。
# 必须参数、关键字参数、默认参数、不定长参数。
# 加了星号 * 的参数会以元组(tuple)的形式导入，存放所有未命名的变量参数。
# 还有一种就是参数带两个星号 **基本语法如下：
# 加了两个星号 ** 的参数会以字典的形式导入。
# **var_args_dict
# *vartuple
#
# 匿名函数
# 使用lambda来创建匿名函数
#
# 语法
# lambda 函数的语法只包含一个语句，如下：
#
# lambda [arg1 [,arg2,.....argn]]:expression

# %% [markdown]
# ## Python3 数据结构
#
# 列表
#
#
# ### 把列表当作堆栈使用
# stack = [3, 4, 5]
# stack.append(5)
# stack.pop()
#
# ### 把列表当队列使用
# 可以把列表最前面元素弹出，当队列使用，但这种使用方法却不快，因为其他元素要一个一个地往前移动。
# from collections import deque
# 一个额外的包，可以当队列使用
#
# ### 列表推导式
# vec = [2, 3, 4]
# [3* x for x in vec]
# [3*x for x in vec if x > 3]
#
# del语句：可以使用del从列表删除一个切割
#
# 字典便利技巧
# for k,v in dict.items():
#     print(k, v)

# %% [markdown]
# ### Python3 模块
#
# import sys
#
# print('命令行参数如下：')
# for i in sys.argv:
#     print(v)
#
# print('\n\nPython路径为：', sys.path, '\n')
#
#
# ### 深入模块
#
# __name__变量
#
# dir()函数
#
# ### 包
# 目录只有包含一个叫__init__.py的文件才会被认为是一个包。
# 最简单的情况，放一个空的:file:__init__.py就可以了，当然这个文件中也可以包含一些初始化代码，或者__all__变量赋值。
#
# 导入语句遵循如下规则：如果包定义文件 __init__.py 存在一个叫做 __all__ 的列表变量，那么在使用 from package import * 的时候就把这个列表中的所有名字作为包内容导入。

# %% [markdown]
# ### Python3 输入和输出
#
# >>> table = {'Google': 1, 'Runoob': 2, 'Taobao': 3}
# >>> print('Runoob: {Runoob:d}; Google: {Google:d}; Taobao: {Taobao:d}'.format(**table))
# Runoob: 2; Google: 1; Taobao: 3
#
# 使用format进行格式化输入输出
#
# ### 读取键盘输入
# str = input("请输入：");
# print ("你输入的内容是: ", str)
#
# ### 读和写文件
#
# | 模式 | 描述 |
# | --- |--- |
# |r|只读方式打开文件|
# |xx+|读写方式打开文件|
# |xxb|二进制方式打开文件|
# |w|打开文件只用写入|
# |a|打开一个文件用于追加|
#
# ### Pickle模块
# 实现基本的数据序列和反序列化

# %% [markdown]
# ### Python3 File
# open()方法

# %% [markdown]
# ### Python3 OS文件/目录方法
#
# os.chdir()改变工作目录
#
# os.chroot()改变当前进程的根目录
#
# os.getcwd()返回当前工作目录
#
# os.getcwdb()返回一个当前工作目录的Unicode对象
#
# os.listdir(path)返回path指定的文件夹包含的文件或文件夹的名字的列表。
#
# os.pardir()获取当前目录的父目录，以字符串形式显示目录名。
#
# ……

# %% [markdown]
# ### Python3 错误和异常
#
# 语法错误
#
# 异常
#
# ### 异常处理
# try/except
# 异常捕捉可以使用try/except
#
# 一个 try 语句可能包含多个except子句，分别来处理不同的特定的异常。最多只有一个分支会被执行。
#
# 处理程序将只针对对应的 try 子句中的异常进行处理，而不是其他的 try 的处理程序中的异常。
#
# 一个except子句可以同时处理多个异常，这些异常将被放在一个括号里成为一个元组，例如:
#
# try/except...else
# try/except 语句还有一个可选的 else 子句，如果使用这个子句，那么必须放在所有的 except 子句之后。
#
# else 子句将在 try 子句没有发生任何异常的时候执行。
#
# try-finally 语句
# try-finally 语句无论是否发生异常都将执行最后的代码。
#
#
# 抛出异常
# Python 使用 raise 语句抛出一个指定的异常。
#
# raise语法格式如下：
#
# raise [Exception [, args [, traceback]]]

# %% [markdown]
# ## Python3 面向对象
#
# ### 面向对象技术简介
# 类（class）：
# 方法：
# 类变量：
# 数据成员：
# 方法重写：
# 局部变量：
# 实例变量：
# 继承：
# 实例化：
# 对象：
#
# Python中的类提供了面向对象编程的所有基本功能：类的继承机制允许多个基类，派生类可以覆盖基类中的任何方法，方法中可以调用基类中的同名方法。
# 【Python允许继承多个基类】
#
#
# __init__()方法
#
# __class__变量
#
# 与一般函数定义不同，类方法必须包含参数 self, 且为第一个参数，self 代表的是类的实例。
#
# 多继承中，方法名同，默认调用的是在括号中参数位置排前父类的方法
#
# ### 类属性与方法
# 类的私有属性
#
# __private_attrs：两个下划线开头，声明该属性为私有。
#
# 类的方法，类方法必须包含参数self。
#
# 类的私有方法
#
# __private_method：两个下划线开头
#
# ### 类的专有方法
# __init__：构造函数
# __del__：析构函数
# __repre__：打印，转换
# __setitem__：按照索引获取值
# __getitem__：按照索引赋值
# __len__：获取长度
# __cmp__：比较运算
# __call__：函数调用
# __add__：加运算
# __sub__：减运算
# __mul__：乘运算
# __truediv__：除运算
# __mod__：求余运算
# __pow__：乘方运算

# %% [markdown]
# ## Python3 命名空间和作用域
#
# 局部空间-->全局空间-->内建空间
#
# global 和 nonlocal关键字
# 当内部作用域想修改外部作用域的变量时，就要用到 global 和 nonlocal 关键字了。

# %% [markdown]
# ## Python3 标准库概览
